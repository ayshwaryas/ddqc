# %%
import pandas as pd

import paths
from filters import initial_qc
from local_config import local
from mc import save_to_csv
from projects_info import N_TISSUES_PROJ
from readers import auto_reader
from utils import safe_mkdir

PATH = "/ahg/regevdata/projects/scqc/"

# %%
def save_to_csv(adata):
    df = adata.obs
    with open(paths.results_dir + "!cells.csv", "w") as fout:
        fout.write(df.to_csv())  # write df to csv

# %%
project = "mc_mca"

# %%
safe_mkdir(PATH + "figure1_data")
safe_mkdir(PATH + "figure1_data/" + project)

# %%
for task_id in range (N_TISSUES_PROJ[project]):
    tissue, is_human, adata = auto_reader(project, task_id, 1)
    adata = initial_qc(adata, 100, 3, is_human)
    
    paths.set_results_dir(PATH + "figure1_data/" + project + "/" + tissue + "/")
    safe_mkdir(paths.results_dir)
    save_to_csv(adata)
# Out:
# 2021-01-31 21:26:00,981 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Bladder/Bladder_dge.csv' is loaded.
# 2021-01-31 21:26:00,987 - pegasusio.readwrite - INFO - Function 'read_input' finished in 6.38s.
# 2021-01-31 21:26:01,140 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.15s.
# 2021-01-31 21:26:01,153 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:26:01,157 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 6.56s.
# 2021-01-31 21:26:03,027 - pegasusio.qc_utils - INFO - After filtration, 3136 out of 3142 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:26:03,032 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.14s.
# 2021-01-31 21:26:03,227 - pegasus.tools.preprocessing - INFO - After filtration, 20208/20670 genes are kept. Among 20208 genes, 17691 genes are robust.
# 2021-01-31 21:26:03,233 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.20s.
# 2021-01-31 21:26:04,323 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/BoneMarrow/BoneMarrow1_dge.csv' is loaded.
# 2021-01-31 21:26:04,329 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.02s.
# 2021-01-31 21:26:09,761 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/BoneMarrow/BoneMarrow2_dge.csv' is loaded.
# 2021-01-31 21:26:09,767 - pegasusio.readwrite - INFO - Function 'read_input' finished in 5.43s.
# 2021-01-31 21:26:16,528 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/BoneMarrow/BoneMarrow3_dge.csv' is loaded.
# 2021-01-31 21:26:16,534 - pegasusio.readwrite - INFO - Function 'read_input' finished in 6.76s.
# 2021-01-31 21:26:17,120 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.57s.
# 2021-01-31 21:26:17,144 - pegasusio.data_aggregation - INFO - Aggregated 3 files.
# 2021-01-31 21:26:17,150 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 13.85s.
# 2021-01-31 21:26:18,760 - pegasusio.qc_utils - INFO - After filtration, 10423 out of 10424 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:26:18,765 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:26:18,978 - pegasus.tools.preprocessing - INFO - After filtration, 18241/19453 genes are kept. Among 18241 genes, 13296 genes are robust.
# 2021-01-31 21:26:18,983 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.21s.
# 2021-01-31 21:26:24,851 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Brain/Brain1_dge.csv' is loaded.
# 2021-01-31 21:26:24,857 - pegasusio.readwrite - INFO - Function 'read_input' finished in 5.69s.
# 2021-01-31 21:26:26,226 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Brain/Brain2_dge.csv' is loaded.
# 2021-01-31 21:26:26,232 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.37s.
# 2021-01-31 21:26:26,673 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.43s.
# 2021-01-31 21:26:26,688 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:26:26,694 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 7.54s.
# 2021-01-31 21:26:28,247 - pegasusio.qc_utils - INFO - After filtration, 4672 out of 4776 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:26:28,253 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.14s.
# 2021-01-31 21:26:28,428 - pegasus.tools.preprocessing - INFO - After filtration, 19964/21979 genes are kept. Among 19964 genes, 16196 genes are robust.
# 2021-01-31 21:26:28,434 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.18s.
# 2021-01-31 21:26:29,291 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Kidney/Kidney1_dge.csv' is loaded.
# 2021-01-31 21:26:29,296 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.77s.
# 2021-01-31 21:26:37,750 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Kidney/Kidney2_dge.csv' is loaded.
# 2021-01-31 21:26:37,756 - pegasusio.readwrite - INFO - Function 'read_input' finished in 8.45s.
# 2021-01-31 21:26:38,270 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.50s.
# 2021-01-31 21:26:38,287 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:26:38,294 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 9.78s.
# 2021-01-31 21:26:39,854 - pegasusio.qc_utils - INFO - After filtration, 6663 out of 6663 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:26:39,860 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.13s.
# 2021-01-31 21:26:40,047 - pegasus.tools.preprocessing - INFO - After filtration, 20132/20987 genes are kept. Among 20132 genes, 15670 genes are robust.
# 2021-01-31 21:26:40,053 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.19s.
# 2021-01-31 21:26:48,953 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Liver/Liver1_dge.csv' is loaded.
# 2021-01-31 21:26:48,959 - pegasusio.readwrite - INFO - Function 'read_input' finished in 8.78s.
# 2021-01-31 21:26:49,330 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Liver/Liver2_dge.csv' is loaded.
# 2021-01-31 21:26:49,335 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.37s.
# 2021-01-31 21:26:49,804 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.46s.
# 2021-01-31 21:26:49,821 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:26:49,827 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 9.66s.
# 2021-01-31 21:26:51,391 - pegasusio.qc_utils - INFO - After filtration, 6424 out of 6424 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:26:51,396 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.13s.
# 2021-01-31 21:26:51,586 - pegasus.tools.preprocessing - INFO - After filtration, 19205/20808 genes are kept. Among 19205 genes, 14801 genes are robust.
# 2021-01-31 21:26:51,592 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.19s.
# 2021-01-31 21:26:55,642 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Lung/Lung1_dge.csv' is loaded.
# 2021-01-31 21:26:55,648 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.94s.
# 2021-01-31 21:26:58,174 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Lung/Lung2_dge.csv' is loaded.
# 2021-01-31 21:26:58,180 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.53s.
# 2021-01-31 21:27:03,755 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Lung/Lung3_dge.csv' is loaded.
# 2021-01-31 21:27:03,761 - pegasusio.readwrite - INFO - Function 'read_input' finished in 5.57s.
# 2021-01-31 21:27:04,339 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.57s.
# 2021-01-31 21:27:04,360 - pegasusio.data_aggregation - INFO - Aggregated 3 files.
# 2021-01-31 21:27:04,366 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 12.67s.
# 2021-01-31 21:27:05,989 - pegasusio.qc_utils - INFO - After filtration, 9111 out of 9113 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:27:05,995 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:27:06,211 - pegasus.tools.preprocessing - INFO - After filtration, 22117/23450 genes are kept. Among 22117 genes, 16552 genes are robust.
# 2021-01-31 21:27:06,216 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.22s.
# 2021-01-31 21:27:12,117 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Involution/MammaryGland.Involution1_dge.csv' is loaded.
# 2021-01-31 21:27:12,123 - pegasusio.readwrite - INFO - Function 'read_input' finished in 5.75s.
# 2021-01-31 21:27:14,539 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Involution/MammaryGland.Involution2_dge.csv' is loaded.
# 2021-01-31 21:27:14,545 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.42s.
# 2021-01-31 21:27:14,986 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.43s.
# 2021-01-31 21:27:15,003 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:27:15,009 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 8.65s.
# 2021-01-31 21:27:16,601 - pegasusio.qc_utils - INFO - After filtration, 6293 out of 6299 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:27:16,606 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:27:16,787 - pegasus.tools.preprocessing - INFO - After filtration, 19009/20365 genes are kept. Among 19009 genes, 15068 genes are robust.
# 2021-01-31 21:27:16,793 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.18s.
# 2021-01-31 21:27:21,510 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Lactation/MammaryGland.Lactation1_dge.csv' is loaded.
# 2021-01-31 21:27:21,516 - pegasusio.readwrite - INFO - Function 'read_input' finished in 4.58s.
# 2021-01-31 21:27:27,969 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Lactation/MammaryGland.Lactation2_dge.csv' is loaded.
# 2021-01-31 21:27:27,975 - pegasusio.readwrite - INFO - Function 'read_input' finished in 6.45s.
# 2021-01-31 21:27:28,385 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.40s.
# 2021-01-31 21:27:28,417 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:27:28,423 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 11.49s.
# 2021-01-31 21:27:30,041 - pegasusio.qc_utils - INFO - After filtration, 6340 out of 15697 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:27:30,046 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:27:30,196 - pegasus.tools.preprocessing - INFO - After filtration, 14551/15761 genes are kept. Among 14551 genes, 9992 genes are robust.
# 2021-01-31 21:27:30,202 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.15s.
# 2021-01-31 21:27:44,611 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Pregnancy/MammaryGland.Pregnancy_dge.csv' is loaded.
# 2021-01-31 21:27:44,617 - pegasusio.readwrite - INFO - Function 'read_input' finished in 14.28s.
# 2021-01-31 21:27:44,752 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.12s.
# 2021-01-31 21:27:44,776 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:27:44,781 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 14.45s.
# 2021-01-31 21:27:46,394 - pegasusio.qc_utils - INFO - After filtration, 9737 out of 9737 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:27:46,399 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.13s.
# 2021-01-31 21:27:46,616 - pegasus.tools.preprocessing - INFO - After filtration, 19644/19673 genes are kept. Among 19644 genes, 14696 genes are robust.
# 2021-01-31 21:27:46,621 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.22s.
# 2021-01-31 21:27:50,036 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Virgin/MammaryGland.Virgin1_dge.csv' is loaded.
# 2021-01-31 21:27:50,042 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.25s.
# 2021-01-31 21:27:52,393 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Virgin/MammaryGland.Virgin2_dge.csv' is loaded.
# 2021-01-31 21:27:52,399 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.35s.
# 2021-01-31 21:27:53,224 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Virgin/MammaryGland.Virgin3_dge.csv' is loaded.
# 2021-01-31 21:27:53,230 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.82s.
# 2021-01-31 21:27:55,238 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MammaryGland.Virgin/MammaryGland.Virgin4_dge.csv' is loaded.
# 2021-01-31 21:27:55,244 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.01s.
# 2021-01-31 21:27:55,810 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.56s.
# 2021-01-31 21:27:55,825 - pegasusio.data_aggregation - INFO - Aggregated 4 files.
# 2021-01-31 21:27:55,831 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 9.05s.
# 2021-01-31 21:27:57,447 - pegasusio.qc_utils - INFO - After filtration, 5677 out of 5677 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:27:57,453 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.14s.
# 2021-01-31 21:27:57,641 - pegasus.tools.preprocessing - INFO - After filtration, 20219/22143 genes are kept. Among 20219 genes, 16147 genes are robust.
# 2021-01-31 21:27:57,647 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.19s.
# 2021-01-31 21:28:17,358 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/MesenchymalStemCells/MesenchymalStemCells_dge.csv' is loaded.
# 2021-01-31 21:28:17,364 - pegasusio.readwrite - INFO - Function 'read_input' finished in 19.60s.
# 2021-01-31 21:28:17,527 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.15s.
# 2021-01-31 21:28:17,559 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:28:17,565 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 19.81s.
# 2021-01-31 21:28:19,315 - pegasusio.qc_utils - INFO - After filtration, 14687 out of 14687 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:28:19,321 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:28:19,597 - pegasus.tools.preprocessing - INFO - After filtration, 17815/17843 genes are kept. Among 17815 genes, 12633 genes are robust.
# 2021-01-31 21:28:19,603 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.28s.
# 2021-01-31 21:28:21,685 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Muscle/Muscle_dge.csv' is loaded.
# 2021-01-31 21:28:21,691 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.83s.
# 2021-01-31 21:28:21,825 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.13s.
# 2021-01-31 21:28:21,835 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:28:21,840 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 1.99s.
# 2021-01-31 21:28:23,344 - pegasusio.qc_utils - INFO - After filtration, 1458 out of 1646 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:28:23,349 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.14s.
# 2021-01-31 21:28:23,497 - pegasus.tools.preprocessing - INFO - After filtration, 15597/17288 genes are kept. Among 15597 genes, 15597 genes are robust.
# 2021-01-31 21:28:23,502 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.15s.
# 2021-01-31 21:28:28,485 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Ovary/Ovary1_dge.csv' is loaded.
# 2021-01-31 21:28:28,491 - pegasusio.readwrite - INFO - Function 'read_input' finished in 4.94s.
# 2021-01-31 21:28:31,761 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Ovary/Ovary2_dge.csv' is loaded.
# 2021-01-31 21:28:31,766 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.27s.
# 2021-01-31 21:28:32,245 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.47s.
# 2021-01-31 21:28:32,259 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:28:32,265 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 8.72s.
# 2021-01-31 21:28:33,840 - pegasusio.qc_utils - INFO - After filtration, 4406 out of 4408 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:28:33,846 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:28:34,031 - pegasus.tools.preprocessing - INFO - After filtration, 20304/21437 genes are kept. Among 20304 genes, 16428 genes are robust.
# 2021-01-31 21:28:34,036 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.19s.
# 2021-01-31 21:28:40,489 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Pancreas/Pancreas_dge.csv' is loaded.
# 2021-01-31 21:28:40,494 - pegasusio.readwrite - INFO - Function 'read_input' finished in 6.36s.
# 2021-01-31 21:28:40,627 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.12s.
# 2021-01-31 21:28:40,641 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:28:40,646 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 6.53s.
# 2021-01-31 21:28:42,194 - pegasusio.qc_utils - INFO - After filtration, 4385 out of 4404 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:28:42,199 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.14s.
# 2021-01-31 21:28:42,368 - pegasus.tools.preprocessing - INFO - After filtration, 19642/20283 genes are kept. Among 19642 genes, 16072 genes are robust.
# 2021-01-31 21:28:42,374 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.17s.
# 2021-01-31 21:28:42,863 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/PeripheralBlood/PeripheralBlood1_dge.csv' is loaded.
# 2021-01-31 21:28:42,869 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.40s.
# 2021-01-31 21:28:46,243 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/PeripheralBlood/PeripheralBlood2_dge.csv' is loaded.
# 2021-01-31 21:28:46,249 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.37s.
# 2021-01-31 21:28:50,880 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/PeripheralBlood/PeripheralBlood3_dge.csv' is loaded.
# 2021-01-31 21:28:50,886 - pegasusio.readwrite - INFO - Function 'read_input' finished in 4.63s.
# 2021-01-31 21:28:51,122 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/PeripheralBlood/PeripheralBlood4_dge.csv' is loaded.
# 2021-01-31 21:28:51,127 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.23s.
# 2021-01-31 21:28:51,629 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/PeripheralBlood/PeripheralBlood5_dge.csv' is loaded.
# 2021-01-31 21:28:51,635 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.50s.
# 2021-01-31 21:28:52,410 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/PeripheralBlood/PeripheralBlood6_dge.csv' is loaded.
# 2021-01-31 21:28:52,416 - pegasusio.readwrite - INFO - Function 'read_input' finished in 0.77s.
# 2021-01-31 21:28:53,076 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.65s.
# 2021-01-31 21:28:53,095 - pegasusio.data_aggregation - INFO - Aggregated 6 files.
# 2021-01-31 21:28:53,101 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 10.64s.
# 2021-01-31 21:28:54,712 - pegasusio.qc_utils - INFO - After filtration, 7943 out of 7966 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:28:54,718 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:28:54,911 - pegasus.tools.preprocessing - INFO - After filtration, 18495/21161 genes are kept. Among 18495 genes, 14037 genes are robust.
# 2021-01-31 21:28:54,916 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.19s.
# 2021-01-31 21:28:58,290 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Placenta/PlacentaE14.1_dge.csv' is loaded.
# 2021-01-31 21:28:58,296 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.23s.
# 2021-01-31 21:29:02,524 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Placenta/PlacentaE14.2_dge.csv' is loaded.
# 2021-01-31 21:29:02,529 - pegasusio.readwrite - INFO - Function 'read_input' finished in 4.23s.
# 2021-01-31 21:29:03,038 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.50s.
# 2021-01-31 21:29:03,053 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:29:03,060 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 8.00s.
# 2021-01-31 21:29:04,650 - pegasusio.qc_utils - INFO - After filtration, 5419 out of 5421 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:29:04,656 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:29:04,835 - pegasus.tools.preprocessing - INFO - After filtration, 20049/21676 genes are kept. Among 20049 genes, 16060 genes are robust.
# 2021-01-31 21:29:04,841 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.18s.
# 2021-01-31 21:29:06,209 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Prostate/Prostate1_dge.csv' is loaded.
# 2021-01-31 21:29:06,215 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.26s.
# 2021-01-31 21:29:08,047 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Prostate/Prostate2_dge.csv' is loaded.
# 2021-01-31 21:29:08,053 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.83s.
# 2021-01-31 21:29:08,420 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.36s.
# 2021-01-31 21:29:08,432 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:29:08,438 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 3.50s.
# 2021-01-31 21:29:10,031 - pegasusio.qc_utils - INFO - After filtration, 2946 out of 2946 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:29:10,037 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.16s.
# 2021-01-31 21:29:10,198 - pegasus.tools.preprocessing - INFO - After filtration, 14112/17198 genes are kept. Among 14112 genes, 11830 genes are robust.
# 2021-01-31 21:29:10,204 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.16s.
# 2021-01-31 21:29:17,219 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/SmallIntestine/SmallIntestine1_dge.csv' is loaded.
# 2021-01-31 21:29:17,225 - pegasusio.readwrite - INFO - Function 'read_input' finished in 6.95s.
# 2021-01-31 21:29:20,612 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/SmallIntestine/SmallIntestine2_dge.csv' is loaded.
# 2021-01-31 21:29:20,618 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.39s.
# 2021-01-31 21:29:23,502 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/SmallIntestine/SmallIntestine3_dge.csv' is loaded.
# 2021-01-31 21:29:23,508 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.88s.
# 2021-01-31 21:29:24,267 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.75s.
# 2021-01-31 21:29:24,288 - pegasusio.data_aggregation - INFO - Aggregated 3 files.
# 2021-01-31 21:29:24,294 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 14.03s.
# 2021-01-31 21:29:26,028 - pegasusio.qc_utils - INFO - After filtration, 8944 out of 8981 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:29:26,034 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.17s.
# 2021-01-31 21:29:26,276 - pegasus.tools.preprocessing - INFO - After filtration, 21227/22358 genes are kept. Among 21227 genes, 15895 genes are robust.
# 2021-01-31 21:29:26,281 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.24s.
# 2021-01-31 21:29:29,395 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Spleen/Spleen_dge.csv' is loaded.
# 2021-01-31 21:29:29,401 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.95s.
# 2021-01-31 21:29:29,544 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.14s.
# 2021-01-31 21:29:29,556 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:29:29,562 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 3.12s.
# 2021-01-31 21:29:31,134 - pegasusio.qc_utils - INFO - After filtration, 2416 out of 2416 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:29:31,140 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:29:31,307 - pegasus.tools.preprocessing - INFO - After filtration, 16196/17545 genes are kept. Among 16196 genes, 14028 genes are robust.
# 2021-01-31 21:29:31,313 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.17s.
# 2021-01-31 21:29:36,572 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Stomach/Stomach_dge.csv' is loaded.
# 2021-01-31 21:29:36,578 - pegasusio.readwrite - INFO - Function 'read_input' finished in 5.20s.
# 2021-01-31 21:29:36,720 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.13s.
# 2021-01-31 21:29:36,733 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:29:36,738 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 5.37s.
# 2021-01-31 21:29:38,346 - pegasusio.qc_utils - INFO - After filtration, 3507 out of 3508 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:29:38,352 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.15s.
# 2021-01-31 21:29:38,534 - pegasus.tools.preprocessing - INFO - After filtration, 18360/18878 genes are kept. Among 18360 genes, 15760 genes are robust.
# 2021-01-31 21:29:38,540 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.18s.
# 2021-01-31 21:29:45,774 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Testis/Testis1_dge.csv' is loaded.
# 2021-01-31 21:29:45,780 - pegasusio.readwrite - INFO - Function 'read_input' finished in 7.16s.
# 2021-01-31 21:30:17,300 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Testis/Testis2_dge.csv' is loaded.
# 2021-01-31 21:30:17,306 - pegasusio.readwrite - INFO - Function 'read_input' finished in 31.52s.
# 2021-01-31 21:30:18,609 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 1.29s.
# 2021-01-31 21:30:18,646 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:30:18,654 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 40.04s.
# 2021-01-31 21:30:20,659 - pegasusio.qc_utils - INFO - After filtration, 19656 out of 19657 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:30:20,665 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.19s.
# 2021-01-31 21:30:21,081 - pegasus.tools.preprocessing - INFO - After filtration, 26891/27200 genes are kept. Among 26891 genes, 18866 genes are robust.
# 2021-01-31 21:30:21,087 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.42s.
# 2021-01-31 21:30:29,376 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Thymus/Thymus1_dge.csv' is loaded.
# 2021-01-31 21:30:29,381 - pegasusio.readwrite - INFO - Function 'read_input' finished in 7.99s.
# 2021-01-31 21:30:30,672 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Thymus/Thymus2_dge.csv' is loaded.
# 2021-01-31 21:30:30,677 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.29s.
# 2021-01-31 21:30:31,137 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.45s.
# 2021-01-31 21:30:31,153 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:30:31,159 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 9.78s.
# 2021-01-31 21:30:32,721 - pegasusio.qc_utils - INFO - After filtration, 5756 out of 5756 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:30:32,727 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.13s.
# 2021-01-31 21:30:32,912 - pegasus.tools.preprocessing - INFO - After filtration, 17745/19164 genes are kept. Among 17745 genes, 14141 genes are robust.
# 2021-01-31 21:30:32,918 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.19s.
# 2021-01-31 21:31:00,802 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/TrophoblastStemCells/TrophoblastStemCells_dge.csv' is loaded.
# 2021-01-31 21:31:00,808 - pegasusio.readwrite - INFO - Function 'read_input' finished in 27.78s.
# 2021-01-31 21:31:00,974 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.15s.
# 2021-01-31 21:31:01,017 - pegasusio.data_aggregation - INFO - Aggregated 1 files.
# 2021-01-31 21:31:01,022 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 28.00s.
# 2021-01-31 21:31:03,029 - pegasusio.qc_utils - INFO - After filtration, 19692 out of 19692 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:31:03,035 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.16s.
# 2021-01-31 21:31:03,382 - pegasus.tools.preprocessing - INFO - After filtration, 21056/21077 genes are kept. Among 21056 genes, 14176 genes are robust.
# 2021-01-31 21:31:03,388 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.35s.
# 2021-01-31 21:31:07,416 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Uterus/Uterus1_dge.csv' is loaded.
# 2021-01-31 21:31:07,422 - pegasusio.readwrite - INFO - Function 'read_input' finished in 3.69s.
# 2021-01-31 21:31:09,927 - pegasusio.readwrite - INFO - csv file '/ahg/regevdata/projects/scqc/data/mouse/mca/Uterus/Uterus2_dge.csv' is loaded.
# 2021-01-31 21:31:09,933 - pegasusio.readwrite - INFO - Function 'read_input' finished in 2.51s.
# 2021-01-31 21:31:10,443 - pegasusio.aggr_data - INFO - Function 'aggregate' finished in 0.50s.
# 2021-01-31 21:31:10,456 - pegasusio.data_aggregation - INFO - Aggregated 2 files.
# 2021-01-31 21:31:10,463 - pegasusio.data_aggregation - INFO - Function 'aggregate_matrices' finished in 6.74s.
# 2021-01-31 21:31:12,204 - pegasusio.qc_utils - INFO - After filtration, 3758 out of 3759 cell barcodes are kept in UnimodalData object GRCm38-rna.
# 2021-01-31 21:31:12,209 - pegasus.tools.preprocessing - INFO - Function 'filter_data' finished in 0.18s.
# 2021-01-31 21:31:12,415 - pegasus.tools.preprocessing - INFO - After filtration, 20501/21848 genes are kept. Among 20501 genes, 17912 genes are robust.
# 2021-01-31 21:31:12,421 - pegasus.tools.preprocessing - INFO - Function 'identify_robust_genes' finished in 0.21s.
