# %%
import pegasus as pg

# %%
adata = pg.read_input("../test.h5ad")
# Out:
# 2020-09-09 22:15:20,826 - pegasusio.readwrite - INFO - h5ad file '../test.h5ad' is loaded.
# 2020-09-09 22:15:20,828 - pegasusio.readwrite - INFO - Function 'read_input' finished in 1.43s.

# %%
pg.scatter(adata, attrs=['louvain_labels'], basis='umap')

# %%
marker_genes = ["Ptprc", "C1qa", "Trem2", "Apod", "Epcam", "Pecam1"]
pg.scatter(adata, attrs=marker_genes, basis='umap', ncols=2)
